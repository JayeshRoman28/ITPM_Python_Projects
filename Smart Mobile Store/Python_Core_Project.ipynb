# %%
print("----- Welcome ------")
print("Smart Mobile Store")
print("------ Menu ------")

orders = []

def SmartMobile_Menu():
     while True:
         print('''\nMain Menu:
                1. Samsung
                2. Vivo
                3. Apple
                4. OnePlus
                5. Oppo
                6. Realme
                7. Redmi
                8. Show Bill
                9. Exit''')
         choice = int(input("Enter your choice: "))
          # -------------------- Samsung --------------------
         if choice == 1:
            print('''-- Samsung available Models--
            1. Galaxy S25 Ultra - Rs. 1,29,999
            2. Galaxy S24 Ultra - Rs. 97,999
            3. Galaxy S23 Ultra - Rs. 75,990
            4. Galaxy S25 + - Rs. 86,999
            5. Galaxy S24 + - Rs. 99,700
            6. Galaxy S23 + - Rs. 94,999
            7. Galaxy S25 FE - Rs. 77,999
            8. Galaxy S24 FE - Rs. 31,999
            9. Galaxy S23 FE - Rs. 39,949
            10. Galaxy Z Fold 7  - Rs. 1,74,999
            11. Return to Main Menu''')
            sub_choice = int(input("Enter your sub choice: "))
            if sub_choice == 1:
                print("You have selected Galaxy S25 Ultra")
                orders.append(("Galaxy S25 Ultra ", 129999))
            elif sub_choice == 2:
                print("You have selected Galaxy S24 Ultra ")
                orders.append(("Galaxy S24 Ultra ", 97999))
            elif sub_choice == 3:
                print("You have selected Galaxy S23 Ultra ")
                orders.append(("Galaxy S25 Ultra ", 75990))
            elif sub_choice == 4:
                print("You have selected  Galaxy S25 + ")
                orders.append((" Galaxy S25 +", 86999))
            elif sub_choice == 5:
                print("You have selected  Galaxy S24 + ")
                orders.append((" Galaxy S24 +", 99700))
            elif sub_choice == 6:
                print("You have selected  Galaxy S23 + ")
                orders.append((" Galaxy S23 +", 94999))
            elif sub_choice == 7:
                print("You have selected Galaxy S25 FE")
                orders.append((" Galaxy S25 FE", 77999))
            elif sub_choice == 8:
                print("You have selected Galaxy S24 FE")
                orders.append((" Galaxy S24 FE", 31900))
            elif sub_choice == 9:
                print("You have selected Galaxy S23 FE")
                orders.append((" Galaxy S23 FE", 39949))
            elif sub_choice == 10:
                print("You have selected Galaxy Z Fold 7 ")
                orders.append((" Galaxy Z Fold 7", 174999))
            elif sub_choice == 11:
                continue
            else:
                print("Invalid choice")
                 # -------------------- Vivo --------------------
         elif choice == 2:
            print('''-- Vivo available Models--
            1. T4 PRO - Rs. 27,999
            2. T4 Ultra - Rs. 35,999
            3. X Fold 5 - Rs. 1,49,999
            4. V60 e - Rs. 29,999
            5. X 200 FE - Rs. 59,999
            6. Y31 PRO 5G - Rs.20,999
            7. Y31 5G - Rs. 14,999
            8. T4x 5G - Rs. 15,499
            9. X 200 PRO - Rs. 94,999
            10. X 200 FE  - Rs. 59,999
            11. Return to Main Menu''')
            sub_choice = int(input("Enter your sub choice: "))
            if sub_choice == 1:
                print("You have selected T4 PRO")
                orders.append(("T4 PRO ",27999))
            elif sub_choice == 2:
                print("You have selected T4 Ultra ")
                orders.append(("T4 Ultra ", 35999))
            elif sub_choice == 3:
                print("You have selected X Fold 5 ")
                orders.append(("X Fold 5 ", 149999))
            elif sub_choice == 4:
                print("You have selected V60 e ")
                orders.append((" V60 e", 29999))
            elif sub_choice == 5:
                print("You have selected X 200 FE ")
                orders.append((" X 200 FE", 59999))
            elif sub_choice == 6:
                print("You have selected Y31 PRO 5G ")
                orders.append((" Y31 PRO 5G", 20900))
            elif sub_choice == 7:
                print("You have selected Y31 5G")
                orders.append((" Y31 5G", 14999))
            elif sub_choice == 8:
                print("You have selected T4x 5G")
                orders.append((" T4x 5G", 15499))
            elif sub_choice == 9:
                print("You have selected X 200 PRO")
                orders.append((" Galaxy S23 FE", 94999))
            elif sub_choice == 10:
                print("You have selected X 200 FE ")
                orders.append((" X 200 FE", 59999))
            elif sub_choice == 11:
                continue
            else:
                print("Invalid choice")
                 # -------------------- Apple --------------------
         elif choice == 3:
            print('''-- Apple available Models --
            1. iPhone 17 PRO - Rs. 1,34,900
            2. iPhone 17 - Rs. 82,900
            3. iPhone 16 - Rs. 69,800
            4. iPhone 16 PRO - Rs. 1,09,900
            5. iPhone 15 PRO - Rs. 1,34,900
            6. iPhone 15 - Rs. 59,900
            7. iPhone 14 PRO - Rs. 1,45,900
            8. iPhone 14 - Rs. 54,900
            9. iPhone 13 PRO - Rs. 1,09,900
            10. iPhone 13 - Rs. 45,000
            11. Return to Main Menu''')
            sub_choice = int(input("Enter your sub choice: "))
            if sub_choice == 1:
                print("You have selected iPhone 17 PRO")
                orders.append(("iPhone 17 PRO", 134900))
            elif sub_choice == 2:
                print("You have selected iPhone 17")
                orders.append(("iPhone 17", 82900))
            elif sub_choice == 3:
                print("You have selected iPhone 16")
                orders.append(("iPhone 16", 69800))
            elif sub_choice == 4:
                print("You have selected iPhone 16 PRO")
                orders.append(("iPhone 16 PRO", 109900))
            elif sub_choice == 5:
                print("You have selected iPhone 15 PRO")
                orders.append(("iPhone 15 PRO", 134900))
            elif sub_choice == 6:
                print("You have selected iPhone 15")
                orders.append(("iPhone 15", 59900))
            elif sub_choice == 7:
                print("You have selected iPhone 14 PRO")
                orders.append(("iPhone 14 PRO", 145900))
            elif sub_choice == 8:
                print("You have selected iPhone 14")
                orders.append(("iPhone 14", 54900))
            elif sub_choice == 9:
                print("You have selected iPhone 13 PRO")
                orders.append(("iPhone 13 PRO", 109900))
            elif sub_choice == 10:
                print("You have selected iPhone 13")
                orders.append(("iPhone 13", 45000))
            elif sub_choice == 11:
                continue
            else:
                print("Invalid choice")
                 # -------------------- OnePlus --------------------
         elif choice == 4:
            print('''-- OnePlus available Models --
            1. OnePlus Nord CE3 - Rs. 24,999
            2. OnePlus Nord 5 - Rs. 31,999
            3. OnePlus 13 - Rs. 51,999
            4. OnePlus 13 Play - Rs. 63,999
            5. OnePlus 13R - Rs. 38,999
            6. OnePlus 12 - Rs. 64,999
            7. OnePlus Nord CE4 Lite 5G - Rs. 17,999
            8. OnePlus Nord 4 - Rs. 21,999
            9. OnePlus Nord CE4 - Rs. 22,999
            10. OnePlus Nord CE3S - Rs. 24,999
            11. Return to Main Menu''')

            sub_choice = int(input("Enter your sub choice: "))
            if sub_choice == 1:
                print("You have selected OnePlus Nord CE3")
                orders.append(("OnePlus Nord CE3", 24999))
            elif sub_choice == 2:
                print("You have selected OnePlus Nord 5")
                orders.append(("OnePlus Nord 5", 31999))
            elif sub_choice == 3:
                print("You have selected OnePlus 13")
                orders.append(("OnePlus 13", 51999))
            elif sub_choice == 4:
                print("You have selected OnePlus 13 Play")
                orders.append(("OnePlus 13 Play", 63999))
            elif sub_choice == 5:
                print("You have selected OnePlus 13R")
                orders.append(("OnePlus 13R", 38999))
            elif sub_choice == 6:
                print("You have selected OnePlus 12")
                orders.append(("OnePlus 12", 64999))
            elif sub_choice == 7:
                print("You have selected OnePlus Nord CE4 Lite 5G")
                orders.append(("OnePlus Nord CE4 Lite 5G", 17999))
            elif sub_choice == 8:
                print("You have selected OnePlus Nord 4")
                orders.append(("OnePlus Nord 4", 21999))
            elif sub_choice == 9:
                print("You have selected OnePlus Nord CE4")
                orders.append(("OnePlus Nord CE4", 22999))
            elif sub_choice == 10:
                print("You have selected OnePlus Nord CE3S")
                orders.append(("OnePlus Nord CE3S", 24999))
            elif sub_choice == 11:
                continue
            else:
                print("Invalid choice")
                # -------------------- Oppo --------------------
         elif choice == 5:
            print('''-- Oppo available Models --
            1. Oppo F31 5G - Rs. 23,999
            2. Oppo F31 PRO 5G - Rs. 26,999
            3. Oppo SG - Rs. 32,999
            4. Oppo Find X7 5G - Rs. 39,999
            5. Oppo Reno 14 5G - Rs. 17,399
            6. Oppo A5 PRO 5G - Rs. 99,999
            7. Oppo A35 Red RAM - Rs. 69,999
            8. Oppo Find X9 PRO - Rs. 69,999
            9. Oppo Find X88 5G - Rs. 48,990
            10. Oppo Find N3 Flip - Rs. 48,990
            11. Return to Main Menu''')
            sub_choice = int(input("Enter your sub choice: "))
            if sub_choice == 1:
                print("You have selected Oppo F31 5G")
                orders.append(("Oppo F31 5G", 23999))
            elif sub_choice == 2:
                print("You have selected Oppo F31 PRO 5G")
                orders.append(("Oppo F31 PRO 5G", 26999))
            elif sub_choice == 3:
                print("You have selected Oppo SG")
                orders.append(("Oppo SG", 32999))
            elif sub_choice == 4:
                print("You have selected Oppo Find X7 5G")
                orders.append(("Oppo Find X7 5G", 39999))
            elif sub_choice == 5:
                print("You have selected Oppo Reno 14 5G")
                orders.append(("Oppo Reno 14 5G", 17399))
            elif sub_choice == 6:
                print("You have selected Oppo A5 PRO 5G")
                orders.append(("Oppo A5 PRO 5G", 99999))
            elif sub_choice == 7:
                print("You have selected Oppo A35 Red RAM")
                orders.append(("Oppo A35 Red RAM", 69999))
            elif sub_choice == 8:
                print("You have selected Oppo Find X9 PRO")
                orders.append(("Oppo Find X9 PRO", 69999))
            elif sub_choice == 9:
                print("You have selected Oppo Find X88 5G")
                orders.append(("Oppo Find X88 5G", 48990))
            elif sub_choice == 10:
                print("You have selected Oppo Find N3 Flip")
                orders.append(("Oppo Find N3 Flip", 48990))
            elif sub_choice == 11:
                continue
            else:
                print("Invalid choice")
                 # -------------------- Realme --------------------
         elif choice == 6:
            print('''-- Realme available Models --
            1. Realme 14 PRO+ 5G - Rs. 28,999
            2. Realme 11 5G - Rs. 24,899
            3. Realme 14 PRO - Rs. 19,999
            4. Realme GT 7 5G - Rs. 29,999
            5. Realme 11 PRO 5G - Rs. 35,999
            6. Realme C73 5G - Rs. 8,999
            7. Realme C53 - Rs. 7,199
            8. Realme C61 - Rs. 8,999
            9. Realme GT 3 240W - Rs. 1,72,829
            10. Realme GT 6 5G - Rs. 1,61,401
            11. Return to Main Menu''')
            sub_choice = int(input("Enter your sub choice: "))
            if sub_choice == 1:
                print("You have selected Realme 14 PRO+ 5G")
                orders.append(("Realme 14 PRO+ 5G", 28999))
            elif sub_choice == 2:
                print("You have selected Realme 11 5G")
                orders.append(("Realme 11 5G", 24899))
            elif sub_choice == 3:
                print("You have selected Realme 14 PRO")
                orders.append(("Realme 14 PRO", 19999))
            elif sub_choice == 4:
                print("You have selected Realme GT 7 5G")
                orders.append(("Realme GT 7 5G", 29999))
            elif sub_choice == 5:
                print("You have selected Realme 11 PRO 5G")
                orders.append(("Realme 11 PRO 5G", 35999))
            elif sub_choice == 6:
                print("You have selected Realme C73 5G")
                orders.append(("Realme C73 5G", 8999))
            elif sub_choice == 7:
                print("You have selected Realme C53")
                orders.append(("Realme C53", 7199))
            elif sub_choice == 8:
                print("You have selected Realme C61")
                orders.append(("Realme C61", 8999))
            elif sub_choice == 9:
                print("You have selected Realme GT 3 240W")
                orders.append(("Realme GT 3 240W", 172829))
            elif sub_choice == 10:
                print("You have selected Realme GT 6 5G")
                orders.append(("Realme GT 6 5G", 161401))
            elif sub_choice == 11:
                continue
            else:
                print("Invalid choice")
                 # -------------------- Redmi --------------------
         elif choice == 7:
            print('''-- Redmi available Models --
            1. Redmi Note 14 PRO+ 5G - Rs. 31,999
            2. Redmi Note 14 5G - Rs. 16,999
            3. Redmi Note 14 PRO - Rs. 23,999
            4. Redmi Note 13 PRO+ 5G - Rs. 19,999
            5. Redmi Note 14 PRO+ 5G (Special) - Rs. 39,999
            6. Redmi 4 3 - Rs. 8,999
            7. Redmi 12 5G - Rs. 9,899
            8. Redmi A5 - Rs. 6,499
            9. Redmi A4 5G - Rs. 8,599
            10. Redmi Note 9 Pro Max - Rs. 9,999
            11. Return to Main Menu''')
            sub_choice = int(input("Enter your sub choice: "))
            if sub_choice == 1:
                print("You have selected Redmi Note 14 PRO+ 5G")
                orders.append(("Redmi Note 14 PRO+ 5G", 31999))
            elif sub_choice == 2:
                print("You have selected Redmi Note 14 5G")
                orders.append(("Redmi Note 14 5G", 16999))
            elif sub_choice == 3:
                print("You have selected Redmi Note 14 PRO")
                orders.append(("Redmi Note 14 PRO", 23999))
            elif sub_choice == 4:
                print("You have selected Redmi Note 13 PRO+ 5G")
                orders.append(("Redmi Note 13 PRO+ 5G", 19999))
            elif sub_choice == 5:
                print("You have selected Redmi Note 14 PRO+ 5G (Special)")
                orders.append(("Redmi Note 14 PRO+ 5G (Special)", 39999))
            elif sub_choice == 6:
                print("You have selected Redmi 4 3")
                orders.append(("Redmi 4 3", 8999))
            elif sub_choice == 7:
                print("You have selected Redmi 12 5G")
                orders.append(("Redmi 12 5G", 9899))
            elif sub_choice == 8:
                print("You have selected Redmi A5")
                orders.append(("Redmi A5", 6499))
            elif sub_choice == 9:
                print("You have selected Redmi A4 5G")
                orders.append(("Redmi A4 5G", 8599))
            elif sub_choice == 10:
                print("You have selected Redmi Note 9 Pro Max")
                orders.append(("Redmi Note 9 Pro Max", 9999))
            elif sub_choice == 11:
                continue
            else:
                print("Invalid choice")
                 # -------------------- Show Bill --------------------
         elif choice == 8:
            print("\n------ BILL ------")
            total = 0
            for items, prices in orders:
                print(f"{items} - Rs.{prices}")
                total += prices
            print("Subtotal:", total)

            # ---- Apply Discount ----
            discount = 0
            if total >= 50000:
                discount = total * 0.10   # 10% discount
                print("Special Offer: 10% discount applied!")
            elif total >= 25000:
                discount = total * 0.05   # 5% 9
                print("Offer: 5% discount applied!")

            final_amount = total - discount
            print(f"Discount: Rs.{discount}")
            print(f"Final Amount: Rs.{final_amount}")

            # ---- Payment Method ----
            print('''\nChoose Payment Method:
                    1. Cash
                    2. Credit/Debit Card
                    3. UPI''')
            pay_choice = int(input("Enter payment option: "))
            if pay_choice == 1:
                print("Payment Successful by Cash!")
            elif pay_choice == 2:
                print("Payment Successful by Card!")
            elif pay_choice == 3:
                print("Payment Successful by UPI!")
            else:
                print("Invalid Payment Option, defaulting to Cash.")
            
            print("\nThank you for shopping with us! ")
          # -------------------- EXIT --------------------
         elif choice == 9:
             print("Thank you! Visit Again.")
             break

         else:
             print("Invalid choice")


SmartMobile_Menu()
# Out:
# ----- Welcome ------
# Smart Mobile Store
# ------ Menu ------
#
# Main Menu
#                 1. Samsung
#                 2. Vivo
#                 3. Apple
#                 4. OnePlus
#                 5. Oppo
#                 6. Realme
#                 7. Redmi
#                 8. Show Bill
#                 9. Exit
# Enter your choice:  2
# -- Vivo available Models--
#             1. T4 PRO - Rs. 27,999
#             2. T4 Ultra - Rs. 35,999
#             3. X Fold 5 - Rs. 1,49,999
#             4. V60 e - Rs. 29,999
#             5. X 200 FE - Rs. 59,999
#             6. Y31 PRO 5G - Rs.20,999
#             7. Y31 5G - Rs. 14,999
#             8. T4x 5G - Rs. 15,499
#             9. X 200 PRO - Rs. 94,999
#             10. X 200 FE  - Rs. 59,999
#             11. Return to Main Menu
# Enter your sub choice:  1
# You have selected T4 PRO
#
# Main Menu
#                 1. Samsung
#                 2. Vivo
#                 3. Apple
#                 4. OnePlus
# ...
